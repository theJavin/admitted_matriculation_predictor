# %%
from LiveAMP import *
db.head('gorvisa')
qry = f"""
select distinct
    gorvisa_natn_code_issue as natn_code,
    (select B.stvnatn_nation from stvnatn B where B.stvnatn_code = A.gorvisa_natn_code_issue) as natn_desc
from gorvisa A
"""
db.execute(qry)
# Out:
#    natn_code            natn_desc
# 0         vm              vietnam
# 1         uk  united kingdom (1s)
# 2         ac  antigua and barbuda
# 3         ci                chile
# 4         tu               turkey
# ..       ...                  ...
# 66        sg              senegal
# 67        da              denmark
# 68        it                italy
# 69        me           montenegro
# 70        bc             botswana
#
# [71 rows x 2 columns]

# %%
db.head('gorvisa')
# Out:
#    gorvisa_pidm  gorvisa_seq_no gorvisa_vtyp_code  gorvisa_visa_number  \
# 0        197965               1                f1                 <NA>
# 1        160144               1                f1                 <NA>
#
#    gorvisa_natn_code_issue  gorvisa_viss_code  gorvisa_visa_start_date  \
# 0                     <NA>               <NA>                     <NA>
# 1                     <NA>               <NA>                     <NA>
#
#    gorvisa_visa_expire_date gorvisa_entry_ind gorvisa_user_id  \
# 0                      <NA>                 n            hess
# 1                      <NA>                 n            hess
#
#   gorvisa_activity_date  gorvisa_visa_req_date  gorvisa_visa_issue_date  \
# 0   2010-10-20 16:57:56                   <NA>                     <NA>
# 1   2010-10-20 16:58:10                   <NA>                     <NA>
#
#    gorvisa_pent_code  gorvisa_no_entries gorvisa_data_origin  \
# ...
